# %% [markdown]
# ---
# title: "2023_Kronensicherung_Plesse_002_LS3"
# author: "Kyell Jensen"
# date: "2024-08-06"
# format: pdf
# editor: visual
# ---

# %% [markdown]
# # 2023_Kronensicherung_Plesse_Kraefte_LS3
# ## LS3: Daten der Kraftmessdosen (lineScale3 Data = LS3)
#
# Nutze eine geeignete Python 3.11 Umgebung (z. B. virtuelle Environment) und installier das Paket linescale3 (LS3) inklusive kj_core und kj_logger und weiteren requirements.

# %% [markdown]
# ## Arbeitsumgebung vorbereiten
#
# Es werden zuerst benötigte Standard-Pakete importiert. Nachfolgend das extra geschriebenen Pakete LS3. Fehler beim Import dieses Pakets sind ggf. Bugs. Es nutzte eine gemeinsame CodeBasis in den Paketen kj_core (Core-Package) und kj_logger (individualisiertes Logging des Verarbeitungs-Prozesses). Diese sollte i. d. R. über die requirements mit installiert werden.

# %% [markdown]
# ### IMPORT: Importieren von Standardbibliotheken
#
# Die folgenden Bibliotheken werden importiert, um grundlegende Funktionen für Strukturierung, Datenverarbeitung, Plotting und statistische Auswertung bereit zu stellen.

# %%
import json
from IPython.display import Markdown, display

# Datenverarbeitung
import numpy as np
import pandas as pd

# %% [markdown]
# ### IMPORT: Importieren eignes Packet lineScale3
#
# Das Paket linescale3 wurde vom Autor (Kyell Jensen) zum einfachen Analysieren, Plotten und zur Interpretation der CSV-Messdaten der lineScale3 Kraftmessdose der Firma lineGrip geschrieben (https://www.linegrip.com/linescale-3/). Das Packet ist auf GitHub verfügbar (https://github.com/kyellsen/linescale3). Nachfolgend wird das Packet und einige dort definierten Klassen importiert.

# %%
import linescale3 as ls3
from linescale3 import Series, Sensor, Measurement
# ls3.help() # Test

# %% [markdown]
# Lade allgemeine Export-Funktionen, um die Daten als Latex-Tabellen zu exportieren

# %%
from kj_core.utils.latex_export import (
    save_latex_table,
    build_data_dict_df
)

# %% [markdown]
# ### IMPORT: Projekt Konfiguration laden
#
# Lege Pfade für Daten-Importe, Daten-Exporte etc. fest (ggf. anpassen an eigene Verzeichnisstruktur), ausgelagert in gemeinsame Config für verschiedene Notebooks

# %%
# Importiere alle Einstellungen aus der project_config.py
from project_config import (
    working_directory,
    analyse_name,
    data_path,
    data_export_directory,
    latex_export_directory
)

# %% [markdown]
# ## IMPORT: lineScale Daten laden
#
# Die Funktion 'ls3.setup' erstellt Instanzen spezifischer Klassen, die für das Paket notwendig sind (CONFIG, LOG_MANAGER, PLOT_MANAGER).
#
# Über die Klasse 'ls3.Series' wird eine neue Messreihe initialisiert und als 'ls3_series' gespeichert. Im Verzeichnis 'ls3_data_path' finden sich die Messdaten von zwei lineScale3 ('LS14BFE6' und 'LS14991E').
# LS14BFE6: Befand sich während der Messung im Zugseil zwischen den Stämmlingen und erfasste die Vorspannung. Es wurden insgesamt 31 Logs (hier Measurements) aufgezeichnet. Eine Messfrequenz von 40 Hz erschien hier ausreichend.
# LS14991E: Befand sich während der Messung in der Kronensicherung und hat die Kraft in der Kronensicherung nach dem Release gemessen. Es wurden 19 Logs erfasst, da die ersten Messungen als Referenz ohne Kronensicherung stattfanden. Hier wurde die maximale Messfrequenz von 1028 Hz gewählt, um Lastspitzen optimal zu erfassen.

# %%
ls3.setup(working_directory=working_directory, log_level="info", safe_logs_to_file=True)

ls3_data_path = data_path / 'LS3'
ls3_series: Series = ls3.classes.Series(name=analyse_name, path=ls3_data_path)
# Out:
# 2025-08-26 15:50:45 [INFO] kj_logger.update_config: <kj_logger.LogManager object at 0x0000023CE34FBCD0> initialized - update_config! Code: 000
# 2025-08-26 15:50:45 [WARNING] kj_core.core_config.set_working_directory: The directory C:\kyellsen\005_Projekte\2024_BA\032_Feldversuch_2023_Plesse\030_Analysen\2023_Kronensicherung_Plesse_Kraefte_Schwingungen\working_directory\ls3 already exists.
# 2025-08-26 15:50:45 [INFO] kj_core.core_config.set_working_directory: Working directory set to C:\kyellsen\005_Projekte\2024_BA\032_Feldversuch_2023_Plesse\030_Analysen\2023_Kronensicherung_Plesse_Kraefte_Schwingungen\working_directory\ls3!
# 2025-08-26 15:50:45 [INFO] kj_core.core_config.__init__: <CoreConfig>
#   Package:            linescale3
#   Working Directory:  C:\kyellsen\005_Projekte\2024_BA\032_Feldversuch_2023_Plesse\030_Analysen\2023_Kronensicherung_Plesse_Kraefte_Schwingungen\working_directory\ls3
#   Plot Directory:     C:\kyellsen\005_Projekte\2024_BA\032_Feldversuch_2023_Plesse\030_Analysen\2023_Kronensicherung_Plesse_Kraefte_Schwingungen\working_directory\ls3\plots
#   Data Directory:     C:\kyellsen\005_Projekte\2024_BA\032_Feldversuch_2023_Plesse\030_Analysen\2023_Kronensicherung_Plesse_Kraefte_Schwingungen\working_directory\ls3\data
#   Database Directory: C:\kyellsen\005_Projekte\2024_BA\032_Feldversuch_2023_Plesse\030_Analysen\2023_Kronensicherung_Plesse_Kraefte_Schwingungen\working_directory\ls3\databases
#  initialized! Code: 001
# 2025-08-26 15:50:45 [INFO] linescale3.setup: ls3: Setup linescale3 package!
# 2025-08-26 15:50:45 [INFO] kj_core.utils.plot_manager.__init__: <PlotManager>
#   Plot Directory:    C:\kyellsen\005_Projekte\2024_BA\032_Feldversuch_2023_Plesse\030_Analysen\2023_Kronensicherung_Plesse_Kraefte_Schwingungen\working_directory\ls3\plots
#   DPI:               300
#   Figure Size:       (8, 6)
#   Seaborn Style:     'whitegrid'
#   Color Palette:     'bright'
#   Grid Enabled:      True
#   Wide Format:       True
#   From Config:       Config
#  initialized! Code: 005
# 2025-08-26 15:50:45 [INFO] linescale3.setup: ls3: linescale3 setup completed.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='1', name='14_41_10', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='2', name='14_47_59', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='3', name='14_55_03', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='4', name='15_04_05', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='5', name='15_08_55', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='6', name='15_12_57', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='7', name='15_16_58', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='8', name='15_21_49', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='9', name='15_25_17', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='10', name='16_11_40', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='11', name='16_17_21', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='12', name='16_23_13', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='13', name='16_37_11', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='14', name='16_41_28', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='15', name='16_46_46', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='16', name='16_56_53', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='17', name='17_01_49', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='18', name='17_05_21', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='19', name='17_16_51', sensor_id='14:99:1E') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='1', name='11_11_55', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='2', name='11_24_23', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='3', name='11_31_12', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='4', name='11_54_33', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='5', name='12_02_03', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='6', name='12_07_09', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='7', name='12_11_49', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='8', name='12_16_13', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='9', name='12_23_21', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='10', name='12_27_13', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:45 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='11', name='14_40_00', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='12', name='14_47_06', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='13', name='14_54_20', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='14', name='15_00_22', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='15', name='15_03_21', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='16', name='15_08_07', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='17', name='15_11_55', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='18', name='15_16_24', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='19', name='15_20_38', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='20', name='15_24_40', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='21', name='16_10_55', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='22', name='16_16_33', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='23', name='16_21_50', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='24', name='16_36_05', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='25', name='16_40_07', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='26', name='16_44_31', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='27', name='16_56_04', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='28', name='17_00_04', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='29', name='17_04_51', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='30', name='17_07_37', sensor_id='14:BF:E6') successful.
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.read_csv: Read CSV for Measurement(id='31', name='17_16_09', sensor_id='14:BF:E6') successful.

# %% [markdown]
# ## ANALYSE: Explorative Datenanalyse

# %% [markdown]
# ### ANALYSE: Berechnung der Vorspannkraft-Ist zum Zeitpunkt des Releases
#
# Berechnung nur für das LS3 im Zugseil sinnvoll.

# %%
sensor_rope: Sensor = ls3_series.sensors[1]
release_force_list = sensor_rope.calculate_release_force()
# Out:
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.502 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.723 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.762 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.740 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.365 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.380 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.369 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=1.964 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=1.978 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=1.947 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.758 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.780 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.764 kN
# 2025-08-26 15:50:46 [ERROR] linescale3.classes.measurement.calculate_release_force: No force values in the specified window: min_force=1, window_sec=5, distance_to_end_sec=3, Object=Measurement(id='14', name='15_00_22', sensor_id='14:BF:E6')
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.307 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.357 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.348 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.028 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.081 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=1.997 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.757 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.766 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.781 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.344 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.344 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.455 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=1.998 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=1.984 kN
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=1.957 kN
# 2025-08-26 15:50:46 [ERROR] linescale3.classes.measurement.calculate_release_force: No force values in the specified window: min_force=1, window_sec=5, distance_to_end_sec=3, Object=Measurement(id='30', name='17_07_37', sensor_id='14:BF:E6')
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_release_force: calculate_release_force successful: release=2.746 kN

# %% [markdown]
# ### ANALYSE: Berechnung des Kraft-Zeit Integrals
#
# Berechnung nur für das LS3 in der KS sinnvoll.

# %%
sensor_ks: Sensor = ls3_series.sensors[0]
sensor_ks.auto_calculate_force_intercept(index_window=(0.5, 1), method="mean")
force_integral_list = sensor_ks.calculate_force_integral()
# Out:
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '14_41_10': intercept=0.058
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '14_47_59': intercept=0.060
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '14_55_03': intercept=0.062
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '15_04_05': intercept=0.040
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '15_08_55': intercept=0.064
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '15_12_57': intercept=0.042
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '15_16_58': intercept=0.046
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '15_21_49': intercept=0.050
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '15_25_17': intercept=0.051
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '16_11_40': intercept=0.442
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '16_17_21': intercept=0.399
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '16_23_13': intercept=0.369
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '16_37_11': intercept=0.369
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '16_41_28': intercept=0.343
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '16_46_46': intercept=0.336
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '16_56_53': intercept=0.333
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '17_01_49': intercept=0.325
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '17_05_21': intercept=0.334
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.apply_force_intercept: apply_force_intercept successful for measurement '17_16_51': intercept=0.059
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.115 kN·s
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.188 kN·s
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=0.912 kN·s
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=0.725 kN·s
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=0.980 kN·s
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=0.874 kN·s
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=0.815 kN·s
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=0.871 kN·s
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=0.721 kN·s
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.322 kN·s
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.697 kN·s
# 2025-08-26 15:50:46 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.436 kN·s
# 2025-08-26 15:50:47 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.217 kN·s
# 2025-08-26 15:50:47 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.409 kN·s
# 2025-08-26 15:50:47 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.456 kN·s
# 2025-08-26 15:50:47 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.335 kN·s
# 2025-08-26 15:50:47 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.095 kN·s
# 2025-08-26 15:50:47 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.450 kN·s
# 2025-08-26 15:50:47 [INFO] linescale3.classes.measurement.calculate_force_integral: calculate_force_integral successful: integral=1.145 kN·s

# %% [markdown]
# ### PLOTTING: Daten der Forcemeter
#
# Da teilweise für jede Messung und jeden Sensor ein Plot generiert wird, werden diese nicht im Notebook direkt angezeigt, sondern im Explorer gespeichert. Die Plots liegen entsprechend im working_directory in den Verzeichnissen ls3/plots/ bzw. ptq/plots.
#
# 'ls3_series.plot_force_vs_time' erstellt für jede Messung für beide eingesetzten LineScales einen Plot, in dem die ermittelte Kraft (force in kN) gegenüber der Zeit (sec_since_start) abgebildet wird. Die Plots werden im Verzeichnis 'ls3/plots/force_vs_time_1/' abgelegt.
#
# 14:BF:E6: Hat die tatsächliche Vorspannung ermittelt und hat entsprechend für alle 29 (-2) Messungen (experiment_id) einen Log aufgezeichnet.
# Aufgrund der Messtechnik wurden 2 Logs erstellt, die keine Messung darstellen. Diese dürfen nicht mit ausgewertet werden (Measurement ID 14 und 30).
#
# 14:99:1E: Hat die Lasten in der Kronensicherung aufgezeichnet und hat entsprechend nur für die 19 (-1) Messungen mit Kronensicherungen einen Log aufgezeichent.

# %%
ls3_series.plot_force_vs_time()
# Out:
# 2025-08-26 15:50:47 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='1', name='14_41_10', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:47 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='2', name='14_47_59', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:48 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='3', name='14_55_03', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:48 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='4', name='15_04_05', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:49 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='5', name='15_08_55', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:49 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='6', name='15_12_57', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:49 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='7', name='15_16_58', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:50 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='8', name='15_21_49', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:50 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='9', name='15_25_17', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:51 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='10', name='16_11_40', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:51 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='11', name='16_17_21', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:51 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='12', name='16_23_13', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:52 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='13', name='16_37_11', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:52 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='14', name='16_41_28', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:53 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='15', name='16_46_46', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:53 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='16', name='16_56_53', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:54 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='17', name='17_01_49', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:54 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='18', name='17_05_21', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:55 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='19', name='17_16_51', sensor_id='14:99:1E')'.
# 2025-08-26 15:50:55 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='1', name='11_11_55', sensor_id='14:BF:E6')'.
# 2025-08-26 15:50:56 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='2', name='11_24_23', sensor_id='14:BF:E6')'.
# 2025-08-26 15:50:56 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='3', name='11_31_12', sensor_id='14:BF:E6')'.
# 2025-08-26 15:50:56 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='4', name='11_54_33', sensor_id='14:BF:E6')'.
# 2025-08-26 15:50:57 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='5', name='12_02_03', sensor_id='14:BF:E6')'.
# 2025-08-26 15:50:57 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='6', name='12_07_09', sensor_id='14:BF:E6')'.
# 2025-08-26 15:50:58 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='7', name='12_11_49', sensor_id='14:BF:E6')'.
# 2025-08-26 15:50:58 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='8', name='12_16_13', sensor_id='14:BF:E6')'.
# 2025-08-26 15:50:59 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='9', name='12_23_21', sensor_id='14:BF:E6')'.
# 2025-08-26 15:50:59 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='10', name='12_27_13', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:00 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='11', name='14_40_00', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:00 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='12', name='14_47_06', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:01 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='13', name='14_54_20', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:02 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='14', name='15_00_22', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:02 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='15', name='15_03_21', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:03 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='16', name='15_08_07', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:03 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='17', name='15_11_55', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:04 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='18', name='15_16_24', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:04 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='19', name='15_20_38', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:04 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='20', name='15_24_40', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:05 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='21', name='16_10_55', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:05 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='22', name='16_16_33', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:06 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='23', name='16_21_50', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:06 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='24', name='16_36_05', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:07 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='25', name='16_40_07', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:07 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='26', name='16_44_31', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:07 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='27', name='16_56_04', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:08 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='28', name='17_00_04', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:08 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='29', name='17_04_51', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:08 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='30', name='17_07_37', sensor_id='14:BF:E6')'.
# 2025-08-26 15:51:09 [INFO] linescale3.classes.measurement.plot_force_vs_time: plot_force_vs_time for measurement 'Measurement(id='31', name='17_16_09', sensor_id='14:BF:E6')'.

# %%
sensor_ks.plot_force_integral()
# Out:
# 2025-08-26 15:51:09 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='1', name='14_41_10', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:10 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='2', name='14_47_59', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:10 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='3', name='14_55_03', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:11 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='4', name='15_04_05', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:11 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='5', name='15_08_55', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:11 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='6', name='15_12_57', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:12 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='7', name='15_16_58', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:12 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='8', name='15_21_49', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:12 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='9', name='15_25_17', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:13 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='10', name='16_11_40', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:13 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='11', name='16_17_21', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:14 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='12', name='16_23_13', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:14 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='13', name='16_37_11', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:15 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='14', name='16_41_28', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:15 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='15', name='16_46_46', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:16 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='16', name='16_56_53', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:16 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='17', name='17_01_49', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:16 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='18', name='17_05_21', sensor_id='14:99:1E')'.
# 2025-08-26 15:51:17 [INFO] linescale3.classes.measurement.plot_force_integral: plot_force_integral for measurement 'Measurement(id='19', name='17_16_51', sensor_id='14:99:1E')'.

# %% [markdown]
# ### ANALYSE: Metadaten bzw. Zusammenfassung der Daten
#
# 'ls3_series.metadata_df' enthält für jeden Log (measurement_id) der 2 LineScales die Metadaten der Messung.
#
# Anmerkung zu `release`: Für jeden Log von 14:BF:E6 (LineScale zur Messung der Vorspannung) wurde die Kraft in kN ermittelt, die kurz vor dem Release vorlag. Diese Kraft ist in den Plots (/ls3/plots/force_vs_time_1/) als grüne Linie markiert. Die entsprechende Funktion befindet sich in 'ls3/classes/measurement.py' und heißt 'get_release_force'.
#
# Anmerkung zu `get_release_force`: Die Funktion filtert alle Kraftwerte über 1.0 kN (Parameter min_force=1.0). Innerhalb der gefilterten Werte wird ein Bereich ausgewählt, der 3 Sekunden vor dem Ende der Messung endet (Parameter distance_to_end_sec=3) und insgesamt 5 Sekunden lang ist (Parameter window_sec=5). Für diesen Zeitraum wird der Mittelwert (Mean) berechnet. Die release_force ist somit der Mittelwert eines 5-sekündigen Plateaus vor dem Release und wird nicht durch kurzzeitige Lastspitzen im Zugseil verfälscht.

# %%
ls3_metadata_df = ls3_series.metadata_df
ls3_metadata_df.head(60)
# Out:
#    measurement_name sensor_id            datetime  measurement_id unit mode  \
# 0          14_41_10  14:99:1E 2022-03-23 14:41:10               1   kN  ABS
# 1          14_47_59  14:99:1E 2022-03-23 14:47:59               2   kN  ABS
# 2          14_55_03  14:99:1E 2022-03-23 14:55:03               3   kN  ABS
# 3          15_04_05  14:99:1E 2022-03-23 15:04:05               4   kN  ABS
# 4          15_08_55  14:99:1E 2022-03-23 15:08:55               5   kN  ABS
# 5          15_12_57  14:99:1E 2022-03-23 15:12:57               6   kN  ABS
# 6          15_16_58  14:99:1E 2022-03-23 15:16:58               7   kN  ABS
# 7          15_21_49  14:99:1E 2022-03-23 15:21:49               8   kN  ABS
# 8          15_25_17  14:99:1E 2022-03-23 15:25:17               9   kN  ABS
# 9          16_11_40  14:99:1E 2022-03-23 16:11:40              10   kN  ABS
# 10         16_17_21  14:99:1E 2022-03-23 16:17:21              11   kN  ABS
# 11         16_23_13  14:99:1E 2022-03-23 16:23:13              12   kN  ABS
# 12         16_37_11  14:99:1E 2022-03-23 16:37:11              13   kN  ABS
# 13         16_41_28  14:99:1E 2022-03-23 16:41:28              14   kN  ABS
# 14         16_46_46  14:99:1E 2022-03-23 16:46:46              15   kN  ABS
# 15         16_56_53  14:99:1E 2022-03-23 16:56:53              16   kN  ABS
# 16         17_01_49  14:99:1E 2022-03-23 17:01:49              17   kN  ABS
# 17         17_05_21  14:99:1E 2022-03-23 17:05:21              18   kN  ABS
# 18         17_16_51  14:99:1E 2022-03-23 17:16:51              19   kN  ABS
# 19         11_11_55  14:BF:E6 2022-03-23 11:11:55               1   kN  ABS
# 20         11_24_23  14:BF:E6 2022-03-23 11:24:23               2   kN  ABS
# 21         11_31_12  14:BF:E6 2022-03-23 11:31:12               3   kN  ABS
# 22         11_54_33  14:BF:E6 2022-03-23 11:54:33               4   kN  ABS
# 23         12_02_03  14:BF:E6 2022-03-23 12:02:03               5   kN  ABS
# 24         12_07_09  14:BF:E6 2022-03-23 12:07:09               6   kN  ABS
# 25         12_11_49  14:BF:E6 2022-03-23 12:11:49               7   kN  ABS
# 26         12_16_13  14:BF:E6 2022-03-23 12:16:13               8   kN  ABS
# 27         12_23_21  14:BF:E6 2022-03-23 12:23:21               9   kN  ABS
# 28         12_27_13  14:BF:E6 2022-03-23 12:27:13              10   kN  ABS
# 29         14_40_00  14:BF:E6 2022-03-23 14:40:00              11   kN  ABS
# 30         14_47_06  14:BF:E6 2022-03-23 14:47:06              12   kN  ABS
# 31         14_54_20  14:BF:E6 2022-03-23 14:54:20              13   kN  ABS
# 32         15_00_22  14:BF:E6 2022-03-23 15:00:22              14   kN  ABS
# 33         15_03_21  14:BF:E6 2022-03-23 15:03:21              15   kN  ABS
# 34         15_08_07  14:BF:E6 2022-03-23 15:08:07              16   kN  ABS
# 35         15_11_55  14:BF:E6 2022-03-23 15:11:55              17   kN  ABS
# 36         15_16_24  14:BF:E6 2022-03-23 15:16:24              18   kN  ABS
# 37         15_20_38  14:BF:E6 2022-03-23 15:20:38              19   kN  ABS
# 38         15_24_40  14:BF:E6 2022-03-23 15:24:40              20   kN  ABS
# 39         16_10_55  14:BF:E6 2022-03-23 16:10:55              21   kN  ABS
# 40         16_16_33  14:BF:E6 2022-03-23 16:16:33              22   kN  ABS
# 41         16_21_50  14:BF:E6 2022-03-23 16:21:50              23   kN  ABS
# 42         16_36_05  14:BF:E6 2022-03-23 16:36:05              24   kN  ABS
# 43         16_40_07  14:BF:E6 2022-03-23 16:40:07              25   kN  ABS
# 44         16_44_31  14:BF:E6 2022-03-23 16:44:31              26   kN  ABS
# 45         16_56_04  14:BF:E6 2022-03-23 16:56:04              27   kN  ABS
# 46         17_00_04  14:BF:E6 2022-03-23 17:00:04              28   kN  ABS
# 47         17_04_51  14:BF:E6 2022-03-23 17:04:51              29   kN  ABS
# 48         17_07_37  14:BF:E6 2022-03-23 17:07:37              30   kN  ABS
# 49         17_16_09  14:BF:E6 2022-03-23 17:16:09              31   kN  ABS
#
#    rel_zero  speed  trig  stop  ...    duration  length  max_index max_force  \
# 0       n/a   1280   0.8   0.0  ...   17.999218   23040       4737      1.48
# 1       n/a   1280   0.8   0.0  ...   17.999218   23040       4721      1.44
# 2       n/a   1280   0.8   0.0  ...   17.999218   23040       3867      1.33
# 3       n/a   1280   0.8   0.0  ...   17.999218   23040       3861      1.01
# 4       n/a   1280   0.8   0.0  ...   17.999218   23040       4730      1.16
# 5       n/a   1280   0.8   0.0  ...   17.999218   23040       4695      1.16
# 6       n/a   1280   0.8   0.0  ...   17.999218   23040       4670      1.01
# 7       n/a   1280   0.8   0.0  ...   17.999218   23040       4684      1.15
# 8       n/a   1280   0.8   0.0  ...   17.999218   23040       4665      1.03
# 9       n/a   1280   1.0   0.0  ...   17.999218   23040       3884      2.59
# 10      n/a   1280   1.0   0.0  ...   17.999218   23040       3879      3.04
# 11      n/a   1280   1.0   0.0  ...   17.999218   23040       3876      3.09
# 12      n/a   1280   1.0   0.0  ...   17.999218   23040       3877      2.84
# 13      n/a   1280   1.0   0.0  ...   17.999218   23040       3877      2.76
# 14      n/a   1280   1.0   0.0  ...   17.999218   23040       3876      2.80
# 15      n/a   1280   1.0   0.0  ...   17.999218   23040       3856      2.33
# 16      n/a   1280   1.0   0.0  ...   17.999218   23040       3877      2.30
# 17      n/a   1280   1.0   0.0  ...   17.999218   23040       3855      2.36
# 18      n/a   1280   1.0   0.0  ...   17.999218   23040       3881      1.74
# 19      n/a     40   0.5   0.5  ...  228.200000    9129       7123      2.57
# 20      n/a     40   0.5   0.5  ...  220.300000    8813       8463      2.88
# 21      n/a     40   0.5   0.5  ...  189.125000    7566       6120      2.86
# 22      n/a     40   0.3   0.5  ...  229.650000    9187       7343      2.82
# 23      n/a     40   0.3   0.5  ...  185.975000    7440       6104      2.41
# 24      n/a     40   0.3   0.5  ...  185.975000    7440       6329      2.41
# 25      n/a     40   0.3   0.5  ...  192.175000    7688       6117      2.41
# 26      n/a     40   0.3   0.5  ...  185.975000    7440       5223      2.01
# 27      n/a     40   0.3   0.5  ...  185.975000    7440       5772      2.02
# 28      n/a     40   0.3   0.5  ...  279.350000   11175       6977      2.01
# 29      n/a     40   0.3   0.5  ...  200.425000    8018       6678      2.84
# 30      n/a     40   0.3   0.5  ...  185.975000    7440       6230      2.85
# 31      n/a     40   0.3   0.5  ...  185.975000    7440       6767      2.85
# 32      n/a     40   0.3   0.5  ...  185.975000    7440       4072      0.55
# 33      n/a     40   0.3   0.5  ...  185.975000    7440       5706      2.40
# 34      n/a     40   0.3   0.5  ...  185.975000    7440       5269      2.41
# 35      n/a     40   0.3   0.5  ...  192.700000    7709       7192      2.45
# 36      n/a     40   0.3   0.5  ...  185.975000    7440       6275      2.07
# 37      n/a     40   0.3   0.5  ...  201.100000    8045       6777      2.13
# 38      n/a     40   0.3   0.5  ...  185.975000    7440       6673      2.06
# 39      n/a     40   0.5   0.5  ...  185.975000    7440       5818      2.83
# 40      n/a     40   0.5   0.5  ...  185.975000    7440       6402      2.84
# 41      n/a     40   0.5   0.5  ...  212.925000    8518       6897      2.85
# 42      n/a     40   0.5   0.5  ...  196.725000    7870       5423      2.42
# 43      n/a     40   0.5   0.5  ...  211.025000    8442       6925      2.43
# 44      n/a     40   0.5   0.5  ...  264.950000   10599       9300      2.51
# 45      n/a     40   0.5   0.5  ...  185.975000    7440       6025      2.05
# 46      n/a     40   0.5   0.5  ...  234.250000    9371       6186      2.08
# 47      n/a     40   0.5   0.5  ...  185.975000    7440       4918      2.01
# 48      n/a     40   0.5   0.5  ...  151.700000    6069       4005      0.60
# 49      n/a     40   0.5   0.5  ...  185.975000    7440       5153      2.82
#
#    min_index  min_force      mean  median  integral  release
# 0         36       0.00  0.111598   0.060  1.114957      NaN
# 1        135       0.00  0.117817   0.060  1.188226      NaN
# 2         81       0.00  0.104375   0.060  0.912268      NaN
# 3         49      -0.01  0.072250   0.040  0.725232      NaN
# 4         73       0.00  0.108828   0.060  0.980189      NaN
# 5       1146      -0.01  0.080535   0.040  0.874301      NaN
# 6          4       0.00  0.082550   0.040  0.814691      NaN
# 7         16       0.00  0.090246   0.050  0.871205      NaN
# 8          6       0.00  0.083470   0.050  0.720548      NaN
# 9         94       0.00  0.404725   0.440  1.321706      NaN
# 10       690       0.00  0.383700   0.380  1.696893      NaN
# 11         4       0.00  0.353530   0.360  1.435639      NaN
# 12       275       0.00  0.346102   0.360  1.216515      NaN
# 13       520       0.00  0.329963   0.330  1.408771      NaN
# 14       260       0.00  0.324260   0.320  1.455661      NaN
# 15       243       0.00  0.317931   0.320  1.334834      NaN
# 16        46       0.00  0.304495   0.320  1.094872      NaN
# 17        48       0.00  0.320037   0.310  1.450102      NaN
# 18        28       0.00  0.112564   0.050  1.144895      NaN
# 19      9128      -0.10  1.188005   1.040       NaN  2.50200
# 20      8812      -0.10  1.249298   1.120       NaN  2.72310
# 21       529      -0.09  1.081462   0.335       NaN  2.76205
# 22      9186      -0.01  1.173566   0.870       NaN  2.73950
# 23      7403      -0.10  0.857964   0.140       NaN  2.36475
# 24      7275      -0.10  0.860966   0.130       NaN  2.38000
# 25         1      -0.08  0.968585   0.310       NaN  2.36920
# 26      6668      -0.10  0.604734   0.020       NaN  1.96440
# 27      7296      -0.10  0.752337   0.110       NaN  1.97830
# 28         0      -0.09  1.163470   1.870       NaN  1.94680
# 29      8017       0.01  1.201922   0.760       NaN  2.75785
# 30      7339      -0.07  1.006413   0.240       NaN  2.78010
# 31      6924      -0.06  0.938508   0.200       NaN  2.76350
# 32       276      -0.06  0.073011   0.000       NaN      NaN
# 33      6973      -0.07  0.730961   0.010       NaN  2.30735
# 34      7148      -0.06  0.926050   0.040       NaN  2.35655
# 35         0      -0.04  1.028355   0.340       NaN  2.34755
# 36      6583      -0.07  0.583161  -0.020       NaN  2.02755
# 37      8044      -0.07  0.880150   0.550       NaN  2.08095
# 38      6682      -0.08  0.483425   0.040       NaN  1.99740
# 39      7025      -0.09  0.886942   0.020       NaN  2.75695
# 40      7160      -0.08  0.737280   0.460       NaN  2.76580
# 41      8517      -0.08  1.128443   0.910       NaN  2.78070
# 42       392      -0.05  1.045867   0.600       NaN  2.34425
# 43      8441      -0.08  1.071758   0.820       NaN  2.34405
# 44         0      -0.07  1.271194   1.930       NaN  2.45465
# 45      7167      -0.09  0.800343  -0.060       NaN  1.99840
# 46         0      -0.06  1.114781   1.860       NaN  1.98435
# 47      6421      -0.09  0.591039   0.000       NaN  1.95740
# 48         0      -0.07  0.217461   0.170       NaN      NaN
# 49      6885      -0.09  1.029777   0.170       NaN  2.74560
#
# [50 rows x 25 columns]

# %% [markdown]
# ## IMPORT: Datendokumentation laden

# %%
ls3_data_dict = ls3_series.create_data_dict()
ls3_data_dict
# Out:
# 2025-08-26 15:51:17 [INFO] linescale3.config.load_label_dict: Label dictionary loaded with 25 entries.
# {'measurement_name': {'Kategorie': 'ls3',
#   'Zeichen': 'filename',
#   'Deutsch': 'Dateiname',
#   'Datentyp': 'object',
#   'Einheit': '-',
#   'Beschreibung': 'Name der Log-Datei bzw. Serienbezeichnung der Messung'},
#  'sensor_id': {'Kategorie': 'ls3',
#   'Zeichen': 'sensor\\_id',
#   'Deutsch': 'Sensor ID',
#   'Datentyp': 'object',
#   'Einheit': '-',
#   'Beschreibung': 'ID des LineScale3 (Seriennummer)'},
#  'measurement_id': {'Kategorie': 'ls3',
#   'Zeichen': '$ID_{\\mathrm{Log}}$',
#   'Deutsch': 'LogNr.',
#   'Datentyp': 'Int64',
#   'Einheit': '-',
#   'Beschreibung': 'Mess-ID (interne LogNr. der LS3)'},
#  'datetime': {'Kategorie': 'ls3',
#   'Zeichen': '$t$',
#   'Deutsch': 'Zeitstempel',
#   'Datentyp': 'object',
#   'Einheit': '-',
#   'Beschreibung': 'Startzeitpunkt der Messung laut Gerät'},
#  'unit': {'Kategorie': 'ls3',
#   'Zeichen': 'unit',
#   'Deutsch': 'Einheit',
#   'Datentyp': 'object',
#   'Einheit': '-',
#   'Beschreibung': 'Einheit der Kraftmessung (hier kN)'},
#  'mode': {'Kategorie': 'ls3',
#   'Zeichen': 'mode',
#   'Deutsch': 'Modus',
#   'Datentyp': 'object',
#   'Einheit': '-',
#   'Beschreibung': 'Messmodus, hier ABS für absolute Kraft'},
#  'speed': {'Kategorie': 'ls3',
#   'Zeichen': '$f$',
#   'Deutsch': 'Abtastrate',
#   'Datentyp': 'Int64',
#   'Einheit': 'Hz',
#   'Beschreibung': 'Messgeschwindigkeit in Hz'},
#  'trig': {'Kategorie': 'ls3',
#   'Zeichen': '$F_{\\mathrm{trig}}$',
#   'Deutsch': 'Triggerkraft',
#   'Datentyp': 'float64',
#   'Einheit': 'kN',
#   'Beschreibung': 'Mindestkraft für Messbeginn'},
#  'pre': {'Kategorie': 'ls3',
#   'Zeichen': '$t_{\\mathrm{pre}}$',
#   'Deutsch': 'Vorlaufzeit',
#   'Datentyp': 'Int64',
#   'Einheit': 's',
#   'Beschreibung': 'Nachträglich ergänzter Zeitraum vor Trigger'},
#  'catch': {'Kategorie': 'ls3',
#   'Zeichen': '$t_{\\mathrm{catch}}$',
#   'Deutsch': 'Aufzeichnungszeit',
#   'Datentyp': 'Int64',
#   'Einheit': 's',
#   'Beschreibung': 'Dauer der Datenerfassung nach Trigger'},
#  'duration': {'Kategorie': 'ls3',
#   'Zeichen': '$\\Delta t$',
#   'Deutsch': 'Messdauer',
#   'Datentyp': 'float64',
#   'Einheit': 's',
#   'Beschreibung': 'Gesamtdauer der Messung'},
#  'length': {'Kategorie': 'ls3',
#   'Zeichen': '$n$',
#   'Deutsch': 'Anzahl Messpunkte',
#   'Datentyp': 'Int64',
#   'Einheit': '-',
#   'Beschreibung': 'Anzahl erfasster Datenpunkte'},
#  'mean': {'Kategorie': 'ls3',
#   'Zeichen': '$\\bar{F}$',
#   'Deutsch': 'Mittlere Kraft',
#   'Datentyp': 'float64',
#   'Einheit': 'kN',
#   'Beschreibung': 'Arithmetisches Mittel der gemessenen Kraft'},
#  'median': {'Kategorie': 'ls3',
#   'Zeichen': '$F_{\\mathrm{median}}$',
#   'Deutsch': 'Median Kraft',
#   'Datentyp': 'float64',
#   'Einheit': 'kN',
#   'Beschreibung': 'Median der gemessenen Kraft'},
#  'release': {'Kategorie': 'ls3',
#   'Zeichen': '$F_{\\mathrm{release}}$',
#   'Deutsch': 'Vorspannkraft-Ist',
#   'Datentyp': 'float64',
#   'Einheit': 'kN',
#   'Beschreibung': 'Tatsächlich realisierte Vorspannkraft im Zugseil bei Release'},
#  'integral': {'Kategorie': 'ls3',
#   'Zeichen': '$\\int F\\,dt$',
#   'Deutsch': 'Kraftintegral',
#   'Datentyp': 'float',
#   'Einheit': 'kN·s',
#   'Beschreibung': 'Zeitliches Integral der Kraft (Fläche unter der Kraft-Zeit-Kurve)'},
#  'datetime_start': {'Kategorie': 'ls3',
#   'Zeichen': '$t_{\\mathrm{start}}$',
#   'Deutsch': 'Startzeitpunkt',
#   'Datentyp': 'object',
#   'Einheit': '-',
#   'Beschreibung': 'Berechneter Startzeitpunkt der Messung'},
#  'datetime_end': {'Kategorie': 'ls3',
#   'Zeichen': '$t_{\\mathrm{end}}$',
#   'Deutsch': 'Endzeitpunkt',
#   'Datentyp': 'object',
#   'Einheit': '-',
#   'Beschreibung': 'Berechneter Endzeitpunkt der Messung'},
#  'max_index': {'Kategorie': 'ls3',
#   'Zeichen': 'idx($F_{\\mathrm{max}}$)',
#   'Deutsch': 'Index der maximalen Kraft',
#   'Datentyp': 'int',
#   'Einheit': '',
#   'Beschreibung': 'Index (Zeitpunkt) des maximalen Kraftwertes'},
#  'max_force': {'Kategorie': 'ls3',
#   'Zeichen': '$F_{\\mathrm{max}}$',
#   'Deutsch': 'Maximale Kraft',
#   'Datentyp': 'float',
#   'Einheit': 'kN',
#   'Beschreibung': 'Maximale Kraftspitze'},
#  'min_index': {'Kategorie': 'ls3',
#   'Zeichen': 'idx($F_{\\mathrm{min}}$)',
#   'Deutsch': 'Index der minimalen Kraft',
#   'Datentyp': 'int',
#   'Einheit': '',
#   'Beschreibung': 'Index (Zeitpunkt) des minimalen Kraftwertes'},
#  'min_force': {'Kategorie': 'ls3',
#   'Zeichen': '$F_{\\mathrm{min}}$',
#   'Deutsch': 'Minimale Kraft',
#   'Datentyp': 'float',
#   'Einheit': 'kN',
#   'Beschreibung': 'Minimaler Kraftwert'},
#  'rel_zero': {'Kategorie': 'ls3',
#   'Zeichen': 'rel\\_zero',
#   'Deutsch': 'Nullpunkt relativ',
#   'Datentyp': 'float64',
#   'Einheit': '-',
#   'Beschreibung': 'Für ABS-Modus nicht relevant (hier NaN)'},
#  'stop': {'Kategorie': 'ls3',
#   'Zeichen': '$t_{\\mathrm{stop}}$',
#   'Deutsch': 'Stopp-Kriterium',
#   'Datentyp': 'float64',
#   'Einheit': 's',
#   'Beschreibung': 'Zeitpunkt der Beendigung der Messung (fixe Dauer bei KS)'},
#  'total': {'Kategorie': 'ls3',
#   'Zeichen': '$t_{\\mathrm{total}}$',
#   'Deutsch': 'Messzeitraum gesamt',
#   'Datentyp': 'Int64',
#   'Einheit': 's',
#   'Beschreibung': 'Gesamtlänge der Messung inkl. Pre-Trigger-Phase'}}

# %% [markdown]
# ## ANALYSE: Datendokumentation für Metadaten ansehen

# %%
# In DataFrame umwandeln
ls3_data_dict_df = build_data_dict_df(ls3_data_dict)

# In Markdown umwandeln und anzeigen
md_text = ls3_data_dict_df.to_markdown(tablefmt="github")
display(Markdown(md_text))
# Out:
# |    | Variable         | Kategorie   | Zeichen                 | Deutsch                   | Datentyp   | Einheit   | Beschreibung                                                      |
# |----|------------------|-------------|-------------------------|---------------------------|------------|-----------|-------------------------------------------------------------------|
# |  0 | measurement_name | ls3         | filename                | Dateiname                 | object     | -         | Name der Log-Datei bzw. Serienbezeichnung der Messung             |
# |  1 | sensor_id        | ls3         | sensor\_id              | Sensor ID                 | object     | -         | ID des LineScale3 (Seriennummer)                                  |
# |  2 | measurement_id   | ls3         | $ID_{\mathrm{Log}}$     | LogNr.                    | Int64      | -         | Mess-ID (interne LogNr. der LS3)                                  |
# |  3 | datetime         | ls3         | $t$                     | Zeitstempel               | object     | -         | Startzeitpunkt der Messung laut Gerät                             |
# |  4 | unit             | ls3         | unit                    | Einheit                   | object     | -         | Einheit der Kraftmessung (hier kN)                                |
# |  5 | mode             | ls3         | mode                    | Modus                     | object     | -         | Messmodus, hier ABS für absolute Kraft                            |
# |  6 | speed            | ls3         | $f$                     | Abtastrate                | Int64      | Hz        | Messgeschwindigkeit in Hz                                         |
# |  7 | trig             | ls3         | $F_{\mathrm{trig}}$     | Triggerkraft              | float64    | kN        | Mindestkraft für Messbeginn                                       |
# |  8 | pre              | ls3         | $t_{\mathrm{pre}}$      | Vorlaufzeit               | Int64      | s         | Nachträglich ergänzter Zeitraum vor Trigger                       |
# |  9 | catch            | ls3         | $t_{\mathrm{catch}}$    | Aufzeichnungszeit         | Int64      | s         | Dauer der Datenerfassung nach Trigger                             |
# | 10 | duration         | ls3         | $\Delta t$              | Messdauer                 | float64    | s         | Gesamtdauer der Messung                                           |
# | 11 | length           | ls3         | $n$                     | Anzahl Messpunkte         | Int64      | -         | Anzahl erfasster Datenpunkte                                      |
# | 12 | mean             | ls3         | $\bar{F}$               | Mittlere Kraft            | float64    | kN        | Arithmetisches Mittel der gemessenen Kraft                        |
# | 13 | median           | ls3         | $F_{\mathrm{median}}$   | Median Kraft              | float64    | kN        | Median der gemessenen Kraft                                       |
# | 14 | release          | ls3         | $F_{\mathrm{release}}$  | Vorspannkraft-Ist         | float64    | kN        | Tatsächlich realisierte Vorspannkraft im Zugseil bei Release      |
# | 15 | integral         | ls3         | $\int F\,dt$            | Kraftintegral             | float      | kN·s      | Zeitliches Integral der Kraft (Fläche unter der Kraft-Zeit-Kurve) |
# | 16 | datetime_start   | ls3         | $t_{\mathrm{start}}$    | Startzeitpunkt            | object     | -         | Berechneter Startzeitpunkt der Messung                            |
# | 17 | datetime_end     | ls3         | $t_{\mathrm{end}}$      | Endzeitpunkt              | object     | -         | Berechneter Endzeitpunkt der Messung                              |
# | 18 | max_index        | ls3         | idx($F_{\mathrm{max}}$) | Index der maximalen Kraft | int        |           | Index (Zeitpunkt) des maximalen Kraftwertes                       |
# | 19 | max_force        | ls3         | $F_{\mathrm{max}}$      | Maximale Kraft            | float      | kN        | Maximale Kraftspitze                                              |
# | 20 | min_index        | ls3         | idx($F_{\mathrm{min}}$) | Index der minimalen Kraft | int        |           | Index (Zeitpunkt) des minimalen Kraftwertes                       |
# | 21 | min_force        | ls3         | $F_{\mathrm{min}}$      | Minimale Kraft            | float      | kN        | Minimaler Kraftwert                                               |
# | 22 | rel_zero         | ls3         | rel\_zero               | Nullpunkt relativ         | float64    | -         | Für ABS-Modus nicht relevant (hier NaN)                           |
# | 23 | stop             | ls3         | $t_{\mathrm{stop}}$     | Stopp-Kriterium           | float64    | s         | Zeitpunkt der Beendigung der Messung (fixe Dauer bei KS)          |
# | 24 | total            | ls3         | $t_{\mathrm{total}}$    | Messzeitraum gesamt       | Int64      | s         | Gesamtlänge der Messung inkl. Pre-Trigger-Phase                   |

# %% [markdown]
# ## EXPORT: Daten exportieren für Weiterverarbeitung (.feather, .csv, .json)

# %%
# DataFrame als Feather
ls3_metadata_df.to_feather(data_export_directory / "ls3.feather")
ls3_metadata_df.to_csv(data_export_directory / "ls3.csv", sep=";", index=False, encoding="utf-8")

# Dict als JSON (UTF-8, sauber eingerückt)
with open(data_export_directory / "ls3_data_dict.json", "w", encoding="utf-8") as f:
    json.dump(ls3_data_dict, f,  indent=4, ensure_ascii=False)

# %%
# Feather laden

# ls3_metadata_df = pd.read_feather(data_export_directory / "ls3_metadata.feather")
# 
# # JSON laden
# with open(data_export_directory / "ls3_data_dict.json", "r", encoding="utf-8") as f:
#     ls3_data_dict = json.load(f)

# %% [markdown]
# ## LATEX-EXPORT: Datendokumentation als Latex-Tabelle exportieren (.tex)

# %%
ls3_data_dict_df = build_data_dict_df(ls3_data_dict, escape_index=True, select_latex_fields=True)
latex_string = ls3_data_dict_df.to_latex(index=False, escape=False)
caption = "Plesse - LS3 Daten Dokumentation"

save_latex_table(latex_string, caption, latex_export_directory)
# Out:
# Content saved to: C:\kyellsen\005_Projekte\2024_BA\032_Feldversuch_2023_Plesse\030_Analysen\2023_Kronensicherung_Plesse_Kraefte_Schwingungen\working_directory\export_latex\plesse_ls3_daten_dokumentation.tex
