# %% [markdown]
# ---
# title: "2023_Treecable_Plesse_V1_Test"
# author: "Kyell Jensen"
# date: "2024-08-06"
# format: pdf
# editor: visual
# ---

# %% [markdown]
# # 2023_Treecable_Plesse_V1_Test
#
# ## Teste Packages und imports

# %%
from analysis_config import cfg

path_data = cfg.paths.data
path_results = cfg.paths.results

path_data, path_results
# Out:
# '../../200_data'
